# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %% [markdown]
# ## Download and explore the dataset

# %%
import pathlib
data_dir = "leaf_photos"
data_dir = pathlib.Path(data_dir)

# %% [markdown]
# ## dataset images count.

# %%
image_count = len(list(data_dir.glob('*/*.jpg')))
print(image_count)
# Out:
# 6264

# %% [markdown]
# Here are some bactrial spot:

# %%
bacterial_spots = list(data_dir.glob('Tomato_Bacterial_Spot/*'))
PIL.Image.open(str(bacterial_spots[0]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=150x150>

# %%
PIL.Image.open(str(bacterial_spots[1]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=150x150>

# %% [markdown]
# And some healthy:

# %%
healthys = list(data_dir.glob('Tomato_Healthy/*'))
PIL.Image.open(str(healthys[0]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=150x150>

# %%
PIL.Image.open(str(healthys[1]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=150x150>

# %% [markdown]
# # Load using keras.preprocessing
#
# Let's load these images off disk using the helpful [image_dataset_from_directory](https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/image_dataset_from_directory) utility. This will take you from a directory of images on disk to a `tf.data.Dataset` in just a couple lines of code. If you like, you can also write your own data loading code from scratch by visiting the [load images](https://www.tensorflow.org/tutorials/load_data/images) tutorial.

# %% [markdown]
# ## Create a dataset

# %% [markdown]
# Define some parameters for the loader:

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# It's good practice to use a validation split when developing your model. Let's use 80% of the images for training, and 20% for validation.

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6268 files belonging to 16 classes.
# Using 5015 files for training.

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6268 files belonging to 16 classes.
# Using 1253 files for validation.

# %% [markdown]
# You can find the class names in the `class_names` attribute on these datasets. These correspond to the directory names in alphabetical order.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['Apple___Apple_scab', 'Apple___Black_rot', 'Apple___Cedar_apple_rust', 'Apple___healthy', 'Carpetweeds', 'Crabgrass', 'Goosegrass', 'Grape___Black_rot', 'Grape___Esca_(Black_Measles)', 'Grape___healthy', 'Tomato_Bacterial_Spot', 'Tomato_Early_Blight', 'Tomato_Healthy', 'Tomato_Leaf_mold', 'Tomato_Septorial_Leaf_Spot', 'Tomato_Yellow_Leaf_Curl_Virus']

# %% [markdown]
# ## Visualize the data
#
# Here are the first 9 images from the training dataset.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (32, 180, 180, 3)
# (32,)

# %% [markdown]
# ## Configure the dataset for performance
#
# Let's make sure to use buffered prefetching so you can yield data from disk without having I/O become blocking. These are two important methods you should use when loading data.
#
# `Dataset.cache()` keeps the images in memory after they're loaded off disk during the first epoch. This will ensure the dataset does not become a bottleneck while training your model. If your dataset is too large to fit into memory, you can also use this method to create a performant on-disk cache.
#
# `Dataset.prefetch()` overlaps data preprocessing and model execution while training.

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ## Standardize the data

# %% [markdown]
# The RGB channel values are in the `[0, 255]` range. This is not ideal for a neural network; in general you should seek to make your input values small. Here, you will standardize values to be in the `[0, 1]` range by using a Rescaling layer.

# %%
normalization_layer = layers.experimental.preprocessing.Rescaling(1./255)

# %% [markdown]
# Note: The Keras Preprocessing utilities and layers introduced in this section are currently experimental and may change.

# %% [markdown]
# There are two ways to use this layer. You can apply it to the dataset by calling map:

# %%
normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
image_batch, labels_batch = next(iter(normalized_ds))
first_image = image_batch[0]
# Notice the pixels values are now in `[0,1]`.
print(np.min(first_image), np.max(first_image))
# Out:
# 0.0 0.9858971

# %% [markdown]
# # Create the model
#
# The model consists of three convolution blocks with a max pool layer in each of them. There's a fully connected layer with 128 units on top of it that is activated by a `relu` activation function. This model has not been tuned for high accuracy, the goal of this tutorial is to show a standard approach.

# %%
num_classes = 16 

model = Sequential([
  layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %% [markdown]
# ## Compile the model
#
# For this tutorial, choose the `optimizers.Adam` optimizer and `losses.SparseCategoricalCrossentropy` loss function. To view training and validation accuracy for each training epoch, pass the `metrics` argument.

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# ## Model summary
#
# View all the layers of the network using the model's `summary` method:

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_1 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 180, 180, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 90, 90, 16)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 90, 90, 32)        4640
#
#  max_pooling2d_1 (MaxPooling  (None, 45, 45, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 45, 45, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 22, 22, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 30976)             0
#
#  dense (Dense)               (None, 128)               3965056
#
#  dense_1 (Dense)             (None, 16)                2064
#
# =================================================================
# Total params: 3,990,704
# Trainable params: 3,990,704
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Train the model
# entire processing by the learning algorithm of the entire train-set. The MNIST train set

# %%
epochs=30
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/30
# 157/157 [==============================] - 49s 311ms/step - loss: 1.4926 - accuracy: 0.5290 - val_loss: 0.8361 - val_accuracy: 0.7390
# Epoch 2/30
# 157/157 [==============================] - 45s 289ms/step - loss: 0.6285 - accuracy: 0.7862 - val_loss: 0.6438 - val_accuracy: 0.7821
# Epoch 3/30
# 157/157 [==============================] - 49s 313ms/step - loss: 0.4615 - accuracy: 0.8465 - val_loss: 0.5658 - val_accuracy: 0.8268
# Epoch 4/30
# 157/157 [==============================] - 63s 402ms/step - loss: 0.3649 - accuracy: 0.8736 - val_loss: 0.5054 - val_accuracy: 0.8332
# Epoch 5/30
# 157/157 [==============================] - 55s 351ms/step - loss: 0.2762 - accuracy: 0.9025 - val_loss: 0.5061 - val_accuracy: 0.8500
# Epoch 6/30
# 157/157 [==============================] - 54s 341ms/step - loss: 0.1953 - accuracy: 0.9328 - val_loss: 0.4372 - val_accuracy: 0.8571
# Epoch 7/30
# 157/157 [==============================] - 45s 285ms/step - loss: 0.1312 - accuracy: 0.9563 - val_loss: 0.4720 - val_accuracy: 0.8611
# Epoch 8/30
# 157/157 [==============================] - 43s 272ms/step - loss: 0.1061 - accuracy: 0.9635 - val_loss: 0.4907 - val_accuracy: 0.8619
# Epoch 9/30
# 157/157 [==============================] - 44s 280ms/step - loss: 0.0931 - accuracy: 0.9663 - val_loss: 0.5074 - val_accuracy: 0.8635
# Epoch 10/30
# 157/157 [==============================] - 45s 288ms/step - loss: 0.0486 - accuracy: 0.9856 - val_loss: 0.5164 - val_accuracy: 0.8731
# Epoch 11/30
# 157/157 [==============================] - 45s 284ms/step - loss: 0.0257 - accuracy: 0.9918 - val_loss: 0.5814 - val_accuracy: 0.8739
# Epoch 12/30
# 157/157 [==============================] - 46s 293ms/step - loss: 0.0240 - accuracy: 0.9922 - val_loss: 0.6298 - val_accuracy: 0.8508
# Epoch 13/30
# 157/157 [==============================] - 43s 274ms/step - loss: 0.0259 - accuracy: 0.9922 - val_loss: 0.5885 - val_accuracy: 0.8763
# Epoch 14/30
# 157/157 [==============================] - 43s 274ms/step - loss: 0.0684 - accuracy: 0.9803 - val_loss: 0.4928 - val_accuracy: 0.8875
# Epoch 15/30
# 157/157 [==============================] - 42s 266ms/step - loss: 0.0158 - accuracy: 0.9956 - val_loss: 0.5722 - val_accuracy: 0.8994
# Epoch 16/30
# 157/157 [==============================] - 42s 271ms/step - loss: 0.0163 - accuracy: 0.9952 - val_loss: 0.5876 - val_accuracy: 0.8891
# Epoch 17/30
# 157/157 [==============================] - 42s 269ms/step - loss: 0.0498 - accuracy: 0.9825 - val_loss: 0.5159 - val_accuracy: 0.8947
# Epoch 18/30
# 157/157 [==============================] - 42s 267ms/step - loss: 0.0271 - accuracy: 0.9918 - val_loss: 0.7293 - val_accuracy: 0.8643
# Epoch 19/30
# 157/157 [==============================] - 43s 272ms/step - loss: 0.0190 - accuracy: 0.9946 - val_loss: 0.7359 - val_accuracy: 0.8667
# Epoch 20/30
# 157/157 [==============================] - 42s 271ms/step - loss: 0.0421 - accuracy: 0.9860 - val_loss: 0.7171 - val_accuracy: 0.8667
# Epoch 21/30
# 157/157 [==============================] - 45s 287ms/step - loss: 0.0061 - accuracy: 0.9980 - val_loss: 0.6088 - val_accuracy: 0.9010
# Epoch 22/30
# 157/157 [==============================] - 50s 316ms/step - loss: 6.6954e-04 - accuracy: 1.0000 - val_loss: 0.6478 - val_accuracy: 0.8970
# Epoch 23/30
# 157/157 [==============================] - 51s 323ms/step - loss: 2.6687e-04 - accuracy: 1.0000 - val_loss: 0.6285 - val_accuracy: 0.9010
# Epoch 24/30
# 157/157 [==============================] - 63s 402ms/step - loss: 1.6730e-04 - accuracy: 1.0000 - val_loss: 0.6392 - val_accuracy: 0.9034
# Epoch 25/30
# 157/157 [==============================] - 60s 380ms/step - loss: 1.3217e-04 - accuracy: 1.0000 - val_loss: 0.6479 - val_accuracy: 0.9034
# Epoch 26/30
# 157/157 [==============================] - 43s 276ms/step - loss: 1.1215e-04 - accuracy: 1.0000 - val_loss: 0.6551 - val_accuracy: 0.9058
# Epoch 27/30
# 157/157 [==============================] - 43s 273ms/step - loss: 9.3653e-05 - accuracy: 1.0000 - val_loss: 0.6643 - val_accuracy: 0.9042
# Epoch 28/30
# 157/157 [==============================] - 42s 267ms/step - loss: 8.0753e-05 - accuracy: 1.0000 - val_loss: 0.6674 - val_accuracy: 0.9058
# Epoch 29/30
# 157/157 [==============================] - 45s 286ms/step - loss: 7.1048e-05 - accuracy: 1.0000 - val_loss: 0.6744 - val_accuracy: 0.9058
# Epoch 30/30
# 157/157 [==============================] - 43s 271ms/step - loss: 6.2212e-05 - accuracy: 1.0000 - val_loss: 0.6792 - val_accuracy: 0.9058

# %% [markdown]
# ## Visualize training results

# %% [markdown]
# Create plots of loss and accuracy on the training and validation sets.

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# As you can see from the plots, training accuracy and validation accuracy are off by large margin and the model has achieved only around 60% accuracy on the validation set.
#
# Let's look at what went wrong and try to increase the overall performance of the model.

# %% [markdown]
# ## Overfitting

# %% [markdown]
# In the plots above, the training accuracy is increasing linearly over time, whereas validation accuracy stalls around 60% in the training process. Also, the difference in accuracy between training and validation accuracy is noticeable—a sign of [overfitting](https://www.tensorflow.org/tutorials/keras/overfit_and_underfit).
#
# When there are a small number of training examples, the model sometimes learns from noises or unwanted details from training examples—to an extent that it negatively impacts the performance of the model on new examples. This phenomenon is known as overfitting. It means that the model will have a difficult time generalizing on a new dataset.
#
# There are multiple ways to fight overfitting in the training process. In this tutorial, you'll use *data augmentation* and add *Dropout* to your model.

# %% [markdown]
# ## Data augmentation

# %% [markdown]
# Overfitting generally occurs when there are a small number of training examples. [Data augmentation](https://www.tensorflow.org/tutorials/images/data_augmentation) takes the approach of generating additional training data from your existing examples by augmenting them using random transformations that yield believable-looking images. This helps expose the model to more aspects of the data and generalize better.
#
# You will implement data augmentation using experimental [Keras Preprocessing Layers](https://www.tensorflow.org/api_docs/python/tf/keras/layers/experimental/preprocessing/?version=nightly). These can be included inside your model like other layers, and run on the GPU.

# %%
data_augmentation = keras.Sequential(
  [
    layers.experimental.preprocessing.RandomFlip("horizontal", 
                                                 input_shape=(img_height, 
                                                              img_width,
                                                              3)),
    layers.experimental.preprocessing.RandomRotation(0.1),
    layers.experimental.preprocessing.RandomZoom(0.1),
  ]
)

# %% [markdown]
# Let's visualize what a few augmented examples look like by applying data augmentation to the same image several times:

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
  for i in range(9):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_images[0].numpy().astype("uint8"))
    plt.axis("off")

# %% [markdown]
# You will use data augmentation to train a model in a moment.

# %% [markdown]
# ## Dropout
#
# Another technique to reduce overfitting is to introduce [Dropout](https://developers.google.com/machine-learning/glossary#dropout_regularization) to the network, a form of *regularization*.
#
# When you apply Dropout to a layer it randomly drops out (by setting the activation to zero) a number of output units from the layer during the training process. Dropout takes a fractional number as its input value, in the form such as 0.1, 0.2, 0.4, etc. This means dropping out 10%, 20% or 40% of the output units randomly from the applied layer.
#
# Let's create a new neural network using `layers.Dropout`, then train it using augmented images.

# %%
model = Sequential([
  data_augmentation,
  layers.experimental.preprocessing.Rescaling(1./255),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %% [markdown]
# ## Compile and train the model

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_1 (Sequential)   (None, 180, 180, 3)       0
#
#  rescaling_2 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d_3 (Conv2D)           (None, 180, 180, 16)      448
#
#  max_pooling2d_3 (MaxPooling  (None, 90, 90, 16)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 90, 90, 32)        4640
#
#  max_pooling2d_4 (MaxPooling  (None, 45, 45, 32)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 45, 45, 64)        18496
#
#  max_pooling2d_5 (MaxPooling  (None, 22, 22, 64)       0
#  2D)
#
#  dropout (Dropout)           (None, 22, 22, 64)        0
#
#  flatten_1 (Flatten)         (None, 30976)             0
#
#  dense_2 (Dense)             (None, 128)               3965056
#
#  dense_3 (Dense)             (None, 16)                2064
#
# =================================================================
# Total params: 3,990,704
# Trainable params: 3,990,704
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = 50
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/50
# 157/157 [==============================] - 50s 316ms/step - loss: 1.3583 - accuracy: 0.5807 - val_loss: 1.0753 - val_accuracy: 0.6313
# Epoch 2/50
# 157/157 [==============================] - 50s 321ms/step - loss: 0.7246 - accuracy: 0.7567 - val_loss: 0.6708 - val_accuracy: 0.7749
# Epoch 3/50
# 157/157 [==============================] - 49s 310ms/step - loss: 0.6276 - accuracy: 0.7815 - val_loss: 0.8389 - val_accuracy: 0.6895
# Epoch 4/50
# 157/157 [==============================] - 49s 312ms/step - loss: 0.5030 - accuracy: 0.8267 - val_loss: 0.6967 - val_accuracy: 0.7598
# Epoch 5/50
# 157/157 [==============================] - 49s 313ms/step - loss: 0.4294 - accuracy: 0.8510 - val_loss: 0.6245 - val_accuracy: 0.8013
# Epoch 6/50
# 157/157 [==============================] - 49s 313ms/step - loss: 0.3855 - accuracy: 0.8636 - val_loss: 0.5077 - val_accuracy: 0.8292
# Epoch 7/50
# 157/157 [==============================] - 49s 312ms/step - loss: 0.3459 - accuracy: 0.8778 - val_loss: 0.4706 - val_accuracy: 0.8308
# Epoch 8/50
# 157/157 [==============================] - 49s 311ms/step - loss: 0.3334 - accuracy: 0.8859 - val_loss: 0.9031 - val_accuracy: 0.7342
# Epoch 9/50
# 157/157 [==============================] - 50s 316ms/step - loss: 0.2886 - accuracy: 0.9035 - val_loss: 0.3078 - val_accuracy: 0.8915
# Epoch 10/50
# 157/157 [==============================] - 51s 323ms/step - loss: 0.2595 - accuracy: 0.9055 - val_loss: 0.5774 - val_accuracy: 0.8164
# Epoch 11/50
# 157/157 [==============================] - 49s 314ms/step - loss: 0.2164 - accuracy: 0.9226 - val_loss: 0.4741 - val_accuracy: 0.8731
# Epoch 12/50
# 157/157 [==============================] - 51s 328ms/step - loss: 0.2444 - accuracy: 0.9151 - val_loss: 0.3474 - val_accuracy: 0.8955
# Epoch 13/50
# 157/157 [==============================] - 50s 316ms/step - loss: 0.2166 - accuracy: 0.9200 - val_loss: 0.2786 - val_accuracy: 0.9042
# Epoch 14/50
# 157/157 [==============================] - 51s 326ms/step - loss: 0.1899 - accuracy: 0.9344 - val_loss: 0.3998 - val_accuracy: 0.8731
# Epoch 15/50
# 157/157 [==============================] - 49s 313ms/step - loss: 0.1901 - accuracy: 0.9272 - val_loss: 0.2945 - val_accuracy: 0.8970
# Epoch 16/50
# 157/157 [==============================] - 49s 313ms/step - loss: 0.1569 - accuracy: 0.9466 - val_loss: 0.3754 - val_accuracy: 0.8843
# Epoch 17/50
# 157/157 [==============================] - 50s 317ms/step - loss: 0.1566 - accuracy: 0.9456 - val_loss: 0.2589 - val_accuracy: 0.9210
# Epoch 18/50
# 157/157 [==============================] - 54s 342ms/step - loss: 0.1618 - accuracy: 0.9434 - val_loss: 0.3807 - val_accuracy: 0.8851
# Epoch 19/50
# 157/157 [==============================] - 50s 322ms/step - loss: 0.1385 - accuracy: 0.9466 - val_loss: 0.5184 - val_accuracy: 0.8587
# Epoch 20/50
# 157/157 [==============================] - 50s 320ms/step - loss: 0.1543 - accuracy: 0.9460 - val_loss: 0.4684 - val_accuracy: 0.8779
# Epoch 21/50
# 157/157 [==============================] - 50s 317ms/step - loss: 0.1404 - accuracy: 0.9517 - val_loss: 0.5506 - val_accuracy: 0.8691
# Epoch 22/50
# 157/157 [==============================] - 53s 341ms/step - loss: 0.1331 - accuracy: 0.9553 - val_loss: 0.3331 - val_accuracy: 0.9002
# Epoch 23/50
# 157/157 [==============================] - 51s 322ms/step - loss: 0.1215 - accuracy: 0.9585 - val_loss: 0.3050 - val_accuracy: 0.9114
# Epoch 24/50
# 157/157 [==============================] - 49s 312ms/step - loss: 0.1084 - accuracy: 0.9629 - val_loss: 0.2985 - val_accuracy: 0.9098
# Epoch 25/50
# 157/157 [==============================] - 49s 313ms/step - loss: 0.1185 - accuracy: 0.9593 - val_loss: 0.3317 - val_accuracy: 0.9082
# Epoch 26/50
# 157/157 [==============================] - 50s 316ms/step - loss: 0.0915 - accuracy: 0.9695 - val_loss: 0.3487 - val_accuracy: 0.9106
# Epoch 27/50
# 157/157 [==============================] - 55s 354ms/step - loss: 0.1328 - accuracy: 0.9535 - val_loss: 0.4230 - val_accuracy: 0.8827
# Epoch 28/50
# 157/157 [==============================] - 56s 355ms/step - loss: 0.1421 - accuracy: 0.9523 - val_loss: 0.4993 - val_accuracy: 0.8835
# Epoch 29/50
# 157/157 [==============================] - 49s 315ms/step - loss: 0.0909 - accuracy: 0.9675 - val_loss: 0.2456 - val_accuracy: 0.9274
# Epoch 30/50
# 157/157 [==============================] - 49s 313ms/step - loss: 0.0953 - accuracy: 0.9647 - val_loss: 0.2445 - val_accuracy: 0.9338
# Epoch 31/50
# 157/157 [==============================] - 49s 313ms/step - loss: 0.0853 - accuracy: 0.9695 - val_loss: 0.4659 - val_accuracy: 0.8907
# Epoch 32/50
# 157/157 [==============================] - 49s 312ms/step - loss: 0.0874 - accuracy: 0.9693 - val_loss: 0.2485 - val_accuracy: 0.9298
# Epoch 33/50
# 157/157 [==============================] - 49s 312ms/step - loss: 0.0875 - accuracy: 0.9681 - val_loss: 0.2464 - val_accuracy: 0.9290
# Epoch 34/50
# 157/157 [==============================] - 50s 319ms/step - loss: 0.0888 - accuracy: 0.9687 - val_loss: 0.4199 - val_accuracy: 0.8875
# Epoch 35/50
# 157/157 [==============================] - 52s 331ms/step - loss: 0.1013 - accuracy: 0.9653 - val_loss: 0.3231 - val_accuracy: 0.8978
# Epoch 36/50
# 157/157 [==============================] - 52s 334ms/step - loss: 0.0787 - accuracy: 0.9725 - val_loss: 0.3562 - val_accuracy: 0.9058
# Epoch 37/50
# 157/157 [==============================] - 51s 323ms/step - loss: 0.0582 - accuracy: 0.9809 - val_loss: 0.2789 - val_accuracy: 0.9266
# Epoch 38/50
# 157/157 [==============================] - 51s 324ms/step - loss: 0.0690 - accuracy: 0.9781 - val_loss: 0.2544 - val_accuracy: 0.9282
# Epoch 39/50
# 157/157 [==============================] - 51s 325ms/step - loss: 0.0779 - accuracy: 0.9741 - val_loss: 0.2562 - val_accuracy: 0.9290
# Epoch 40/50
# 157/157 [==============================] - 51s 323ms/step - loss: 0.0605 - accuracy: 0.9779 - val_loss: 0.2749 - val_accuracy: 0.9330
# Epoch 41/50
# 157/157 [==============================] - 51s 324ms/step - loss: 0.0771 - accuracy: 0.9741 - val_loss: 0.3380 - val_accuracy: 0.9210
# Epoch 42/50
# 157/157 [==============================] - 52s 331ms/step - loss: 0.0699 - accuracy: 0.9759 - val_loss: 0.5457 - val_accuracy: 0.8675
# Epoch 43/50
# 157/157 [==============================] - 61s 391ms/step - loss: 0.0570 - accuracy: 0.9805 - val_loss: 0.3742 - val_accuracy: 0.9122
# Epoch 44/50
# 157/157 [==============================] - 60s 381ms/step - loss: 0.0680 - accuracy: 0.9739 - val_loss: 0.2636 - val_accuracy: 0.9346
# Epoch 45/50
# 157/157 [==============================] - 58s 372ms/step - loss: 0.0752 - accuracy: 0.9745 - val_loss: 0.2040 - val_accuracy: 0.9505
# Epoch 46/50
# 157/157 [==============================] - 59s 378ms/step - loss: 0.0685 - accuracy: 0.9783 - val_loss: 0.1849 - val_accuracy: 0.9457
# Epoch 47/50
# 157/157 [==============================] - 55s 352ms/step - loss: 0.0639 - accuracy: 0.9795 - val_loss: 0.3415 - val_accuracy: 0.9162
# Epoch 48/50
# 157/157 [==============================] - 61s 386ms/step - loss: 0.0565 - accuracy: 0.9815 - val_loss: 0.2439 - val_accuracy: 0.9377
# Epoch 49/50
# 157/157 [==============================] - 60s 384ms/step - loss: 0.0647 - accuracy: 0.9771 - val_loss: 0.2544 - val_accuracy: 0.9330
# Epoch 50/50
# 157/157 [==============================] - 57s 363ms/step - loss: 0.0618 - accuracy: 0.9793 - val_loss: 0.2783 - val_accuracy: 0.9322

# %% [markdown]
# ## Visualize training results
#
# After applying data augmentation and Dropout, there is less overfitting than before, and training and validation accuracy are closer aligned.

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# # Saving Model

# %%
model.save_weights('my_checkpoint.ckpt')

# %% [markdown]
# ## Validation accuracy

# %%
np.max(val_acc)
# Out:
# 0.9505187273025513

# %% [markdown]
# ## Test Predict on new data

# %%
test_image_path = "bac_spot.jpg"

img = keras.preprocessing.image.load_img(
    test_image_path, target_size=(img_height, img_width)
)
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
PIL.Image.open(test_image_path)
# Out:
# This image most likely belongs to Tomato_Bacterial_Spot with a 100.00 percent confidence.
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=150x150>

# %%
test_image_path2 = "erly_blight.jpg"

img = keras.preprocessing.image.load_img(
    test_image_path2, target_size=(img_height, img_width)
)
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
PIL.Image.open(test_image_path2)
# Out:
# This image most likely belongs to Tomato_Early_Blight with a 99.54 percent confidence.
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=150x150>

# %%
test_image_path2 = "healthy.jpg"

img = keras.preprocessing.image.load_img(
    test_image_path2, target_size=(img_height, img_width)
)
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
PIL.Image.open(test_image_path2)
# Out:
# This image most likely belongs to Tomato_Healthy with a 97.92 percent confidence.
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=150x150>

# %%
test_image_path2 = "leaf_mold.jpg" #erly_blight.jpg" #"

img = keras.preprocessing.image.load_img(
    test_image_path2, target_size=(img_height, img_width)
)
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
PIL.Image.open(test_image_path2)
# Out:
# This image most likely belongs to Tomato_Leaf_mold with a 97.06 percent confidence.
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=150x150>

# %%
test_image_path2 = "septorial_leaf_spot.jpg"

img = keras.preprocessing.image.load_img(
    test_image_path2, target_size=(img_height, img_width)
)
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
PIL.Image.open(test_image_path2)
# Out:
# This image most likely belongs to Tomato_Septorial_Leaf_Spot with a 99.07 percent confidence.
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=150x150>

# %%
test_image_path2 = "yellow_leaf_curl_virus.jpg"

img = keras.preprocessing.image.load_img(
    test_image_path2, target_size=(img_height, img_width)
)
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
PIL.Image.open(test_image_path2)
# Out:
# This image most likely belongs to Tomato_Yellow_Leaf_Curl_Virus with a 100.00 percent confidence.
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=150x150>
